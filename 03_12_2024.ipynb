# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthchica31/IA-2024-2/blob/main/03_12_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
movies = pd.read_csv('/content/movies.csv')
ratings = pd.read_csv('/content/ratings.csv')
tags= pd.read_csv('/content/tags.csv')

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
print(movies.index)
print(ratings.index)
print(tags.index)
# Out:
# RangeIndex(start=0, stop=9742, step=1)
# RangeIndex(start=0, stop=100836, step=1)
# RangeIndex(start=0, stop=3683, step=1)

# %%
print(movies.columns)
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247

# %%
print(ratings['rating'].describe())
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
print(ratings['rating'].mode())
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
rating.shape
# Out:
# (100836, 4)

# %%
tags.shape
# Out:
# (3683, 4)

# %%
movies.shape
# Out:
# (9742, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
# %matplotlib inline
ratings.hist(column='rating', figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)
